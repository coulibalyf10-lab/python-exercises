# %%
name="adja"

# %%
print(name)
# Out:
# adja

# %%
num1=6
num2=3
s=num1+num2
print(s)
# Out:
# 9

# %%
is_raising='true'
print('is raising')
# Out:
# is raising

# %%
favorite_number=input()
print('your favorite number')
# Out:
# 9
# your favorite number

# %%
number = int("100")
print(number)
print(type(number))
# Out:
# 100
# <class 'int'>

# %%
price = 9.99
price_int = int(price)
print(price_int)
# Out:
# 9

# %% [raw]
# The decimal part is removed.
# So 9.99 becomes 9.

# %%
text = """Hello!
This is a multi-line string."""
print(text)
# Out:
# Hello!
# This is a multi-line string.

# %%
print(" Hello " *5)
# Out:
#  Hello  Hello  Hello  Hello  Hello

# %%
message=" My score is "+ str(100)
print(message)
# Out:
#  My score is 100

# %%
result = "apple" in "I have an apple and a banana"
print(result)
# Out:
# True

# %%
radius=5
area=3.14*radius**2
print(area)
# Out:
# 78.5

# %%
print(17 % 2 == 0)
# Out:
# False

# %%
x=5
x+=10
print(x)
# Out:
# 15

# %%
a = 8
b = 10
print(a > b)
print(a <= b)
# Out:
# False
# True

# %%
age = 16
print(age >= 13 and age <= 19)
# Out:
# True

# %%
char = 'y'
print(char == 'y' or char == 'n')
# Out:
# True

# %%
is_logged_in = True
print(not is_logged_in)
# Out:
# False

# %%
list_a = [1, 2, 3]
list_b = [1, 2, 3]
print(list_a is list_b)
# Out:
# False

# %%
print(5 in [1, 2, 3, 4, 5])
# Out:
# True

# %%
value = None
print(value is None)
# Out:
# True

# %%
n = 5
if n> 0:
    print('positive')
# Out:
# positive

# %%
number = 4
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
grade = 85
if grade < 50:
    print("F")
elif grade <= 69:
    print("C")
elif grade <= 89:
    print("B")
else:
    print("A")
# Out:
# B

# %%
for fruit in ['apple', 'banana', 'cherry']:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
total = 0
for i in range(1, 11):
    total += i
print(total)
# Out:
# 55

# %%
i = 5
while i >= 1:
    print(i)
    i -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
while True:
    user_input = input("Type something (type 'stop' to end): ")
    if user_input == "stop":
        break
# Out:
# Type something (type 'stop' to end): stop

# %%
for i in range(4):
    for j in range(4):
        print("#", end=" ")
    print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(1, 11):
    if i == 5:
        print(i)
# Out:
# 5

# %%
for i in range(1, 11):
    if i == 5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
def greet():
    print("Hello, there!")
greet()
# Out:
# Hello, there!

# %%
def multiply(a, b):
    return a * b
print(multiply(3, 4))
# Out:
# 12

# %%
def describe_pet(pet_name, animal_type="cat"):
    print(f"I have a cat named catty.")
describe_pet("catty")
# Out:
# I have a cat named catty.

# %%
def get_max(numbers):
    return max(numbers)
print(get_max([1, 5, 8, 9]))
# Out:
# 9

# %%
def local_example():
    x = 10
    print(x)
local_example()
# Out:
# 10

# %%
global_var = "I am global"

def show_global():
    print(global_var)
show_global()
# Out:
# I am global

# %%
square = lambda x: x ** 2
print(square(5))
# Out:
# 25

# %%
evens = list(filter(lambda x: x % 2 == 0, [1, 2, 3, 4, 5, 6]))
print(evens)
# Out:
# [2, 4, 6]

# %%
fahrenheit = list(map(lambda c: c * 9/5 + 32, [0, 10, 20]))
print(fahrenheit)
# Out:
# [32.0, 50.0, 68.0]

# %%
def countdown(n):
    if n == 0:
        return
    print(n)
    countdown(n - 1)
countdown(n)
# Out:
# 5
# 4
# 3
# 2
# 1
