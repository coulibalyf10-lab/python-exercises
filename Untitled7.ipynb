# %%
import pandas as pd
import numpy as np

# %%
names = pd.Series(['Alice', 'Bob', 'Charlie'])
print("1. Series:")
print(names)
# Out:
# 1. Series:
# 0      Alice
# 1        Bob
# 2    Charlie
# dtype: object

# %%
data = { 'Name': ['Anna', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]}
df = pd.DataFrame(data)
print("\n2. DataFrame:")
print(df)
# Out:
# 2. DataFrame:
#       Name  Age
# 0     Anna   25
# 1      Bob   30
# 2  Charlie   35

# %%
print("\n3. First 2 rows:")
print(df.head(2))
# Out:
# 3. First 2 rows:
#    Name  Age
# 0  Anna   25
# 1   Bob   30

# %%
print("\n4. Age column:")
print(df['Age'])
# Out:
# 4. Age column:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
print("\n5. DataFrame info:")
df.info()
# Out:
# 5. DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
print("\n6. Age > 25:")
print(df[df['Age'] > 25])
# Out:
# 6. Age > 25:
#       Name  Age
# 1      Bob   30
# 2  Charlie   35

# %%
print("\n8. Descriptive statistics for Age:")
print(df['Age'].describe())
# Out:
# 8. Descriptive statistics for Age:
# count     3.0
# mean     30.0
# std       5.0
# min      25.0
# 25%      27.5
# 50%      30.0
# 75%      32.5
# max      35.0
# Name: Age, dtype: float64

# %%
df_missing = pd.DataFrame({'A': [1, 2, np.nan]})
print("\n9. DataFrame with missing value:")
print(df_missing)
# Out:
# 9. DataFrame with missing value:
#      A
# 0  1.0
# 1  2.0
# 2  NaN

# %%
data_csv='Name,Age, Anna,25, Bob,30; Charlie,35'
data
# Out:
# {'Name': ['Anna', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %%
plt.plot([1, 4, 2, 5])
plt.title("My First Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 5, 3]

plt.scatter(x, y)
plt.show()

# %%
categories = ['A', 'B', 'C']
values = [5, 7, 3]

plt.bar(categories, values)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
plt.figure()

plt.subplot(1, 2, 1)
plt.plot([1, 2, 3, 4])

plt.subplot(1, 2, 2)
plt.bar(['A', 'B', 'C'], [5, 7, 3])

plt.show()

# %%
plt.plot([1, 2, 3, 4], 'r--')
plt.show()

# %%
y1 = [1, 2, 3]
y2 = [3, 2, 1]

plt.plot(y1, label='Line 1')
plt.plot(y2, label='Line 2')
plt.legend()
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.xlim(0, 10)
plt.ylim(-5, 5)
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.savefig("my_plot.png")
plt.show()
